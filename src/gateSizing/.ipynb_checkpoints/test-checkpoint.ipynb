# %%
import test_infiniteLadder
import numpy as np

# %%
def testAlgorithms_CVXPY_GP():

    # number of testing
    numberOfIterations = 15
    step = 1

    numberOfGatesStart = 10
    numberOfBins = 15

    interval = (-4, 25)

    # for saving values of the last gates and calculating error
    rvs_nonPrecise = np.zeros((numberOfIterations, 2))
    rvs_Precise = np.zeros((numberOfIterations, 2))
    rvs_MonteCarlo = np.zeros((numberOfIterations, 2))

    results = {}

    # MonteCarlo
    for iter in range(0, numberOfIterations):
        numGates = numberOfGatesStart + iter * step
        lastGate = test_infiniteLadder.MonteCarlo(numGates)

        # saving values
        rvs_MonteCarlo[iter, 0] = lastGate[0]
        rvs_MonteCarlo[iter, 1] = lastGate[1]

    # test precise
    for iter in range(0, numberOfIterations):
        print("\n\n" + str(iter) + ". iteration: \n\n")

        numGates = numberOfGatesStart + iter * step
        lastGate, time = test_infiniteLadder.mainCVXPY_GP(numGates, numberOfBins, interval)

        # saving values
        rvs_Precise[iter, 0] = lastGate[0]
        rvs_Precise[iter, 1] = lastGate[1]

        # print(np.abs(rvs_Precise[iter, :] - rvs_MonteCarlo[iter, :]) / rvs_MonteCarlo[iter, :])

        MAPE = 100 * np.abs(np.divide(rvs_Precise[iter, :] - rvs_MonteCarlo[iter, :], rvs_MonteCarlo[iter, :]))

        print(MAPE)

        if iter != 0:
            prevError = np.zeros(2)
            prevError[0] = results[(numGates - step, True)][3]
            prevError[1] = results[(numGates - step, True)][4]

            MAPE = (MAPE + (prevError) *(iter)) / (iter + 1)

        results[(numGates, True)] = (-1, -1, time, MAPE[0], MAPE[1], -1, -1, -1,
                                     -1, -1)

        # print results
        print("\n\n" + str(results))

# %%
    testAlgorithms_CVXPY_GP()
# Out:
# 0. iteration:
#
#
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Aug 16 09:00:43 AM: Your problem has 635 variables, 635 constraints, and 0 parameters.
# (CVXPY) Aug 16 09:00:43 AM: It is compliant with the following grammars: DGP
# (CVXPY) Aug 16 09:00:43 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 16 09:00:43 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:43 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 16 09:00:43 AM: Reduction chain: Dgp2Dcp -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 16 09:00:43 AM: Applying reduction Dgp2Dcp
# (CVXPY) Aug 16 09:00:43 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 16 09:00:43 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 16 09:00:43 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 16 09:00:44 AM: Applying reduction MOSEK
# (CVXPY) Aug 16 09:00:44 AM: Finished problem compilation (took 1.470e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:44 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Aug 16 09:00:44 AM: Problem
# (CVXPY) Aug 16 09:00:44 AM:   Name                   :
# (CVXPY) Aug 16 09:00:44 AM:   Objective sense        : max
# (CVXPY) Aug 16 09:00:44 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 16 09:00:44 AM:   Constraints            : 4331
# (CVXPY) Aug 16 09:00:44 AM:   Cones                  : 3425
# (CVXPY) Aug 16 09:00:44 AM:   Scalar variables       : 11181
# (CVXPY) Aug 16 09:00:44 AM:   Matrix variables       : 0
# (CVXPY) Aug 16 09:00:44 AM:   Integer variables      : 0
# (CVXPY) Aug 16 09:00:44 AM:
# (CVXPY) Aug 16 09:00:44 AM: Optimizer started.
# (CVXPY) Aug 16 09:00:44 AM: Presolve started.
# (CVXPY) Aug 16 09:00:44 AM: Linear dependency checker started.
# (CVXPY) Aug 16 09:00:44 AM: Linear dependency checker terminated.
# (CVXPY) Aug 16 09:00:44 AM: Eliminator started.
# (CVXPY) Aug 16 09:00:44 AM: Freed constraints in eliminator : 35
# (CVXPY) Aug 16 09:00:44 AM: Eliminator terminated.
# (CVXPY) Aug 16 09:00:44 AM: Eliminator started.
# (CVXPY) Aug 16 09:00:44 AM: Freed constraints in eliminator : 0
# (CVXPY) Aug 16 09:00:44 AM: Eliminator terminated.
# (CVXPY) Aug 16 09:00:44 AM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Aug 16 09:00:44 AM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 16 09:00:44 AM: Lin. dep.  - number                 : 0
# (CVXPY) Aug 16 09:00:44 AM: Presolve terminated. Time: 0.01
# (CVXPY) Aug 16 09:00:44 AM: Problem
# (CVXPY) Aug 16 09:00:44 AM:   Name                   :
# (CVXPY) Aug 16 09:00:44 AM:   Objective sense        : max
# (CVXPY) Aug 16 09:00:44 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 16 09:00:44 AM:   Constraints            : 4331
# (CVXPY) Aug 16 09:00:44 AM:   Cones                  : 3425
# (CVXPY) Aug 16 09:00:44 AM:   Scalar variables       : 11181
# (CVXPY) Aug 16 09:00:44 AM:   Matrix variables       : 0
# (CVXPY) Aug 16 09:00:44 AM:   Integer variables      : 0
# (CVXPY) Aug 16 09:00:44 AM:
# (CVXPY) Aug 16 09:00:44 AM: Optimizer  - threads                : 8
# (CVXPY) Aug 16 09:00:44 AM: Optimizer  - solved problem         : the primal
# (CVXPY) Aug 16 09:00:44 AM: Optimizer  - Constraints            : 4005
# (CVXPY) Aug 16 09:00:44 AM: Optimizer  - Cones                  : 3425
# (CVXPY) Aug 16 09:00:44 AM: Optimizer  - Scalar variables       : 10855             conic                  : 10275
# (CVXPY) Aug 16 09:00:44 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Aug 16 09:00:44 AM: Factor     - setup time             : 0.02              dense det. time        : 0.00
# (CVXPY) Aug 16 09:00:44 AM: Factor     - ML order time          : 0.01              GP order time          : 0.00
# (CVXPY) Aug 16 09:00:44 AM: Factor     - nonzeros before factor : 4.98e+04          after factor           : 1.22e+05
# (CVXPY) Aug 16 09:00:44 AM: Factor     - dense dim.             : 0                 flops                  : 5.46e+06
# (CVXPY) Aug 16 09:00:44 AM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Aug 16 09:00:44 AM: 0   2.3e+01  4.6e+01  3.4e+03  0.00e+00   -3.405254155e+03  0.000000000e+00   1.0e+00  0.05
# (CVXPY) Aug 16 09:00:44 AM: 1   1.7e+01  3.4e+01  2.8e+03  -8.47e-01  -3.309322747e+03  5.558647086e+00   7.3e-01  0.08
# (CVXPY) Aug 16 09:00:44 AM: 2   1.3e+01  2.7e+01  2.4e+03  -7.87e-01  -3.193501895e+03  1.865416929e+01   5.8e-01  0.11
# (CVXPY) Aug 16 09:00:45 AM: 39  7.1e-09  1.1e-08  5.1e-11  9.96e-01   -1.384414703e+01  -1.384414365e+01  2.3e-10  0.79
# (CVXPY) Aug 16 09:00:45 AM: 40  7.1e-09  1.1e-08  5.1e-11  9.96e-01   -1.384414704e+01  -1.384414366e+01  2.3e-10  0.82
# (CVXPY) Aug 16 09:00:45 AM: 41  7.1e-09  1.1e-08  4.9e-11  9.96e-01   -1.384414729e+01  -1.384414399e+01  2.3e-10  0.85
# (CVXPY) Aug 16 09:00:45 AM: 42  7.1e-09  1.1e-08  4.9e-11  9.96e-01   -1.384414729e+01  -1.384414399e+01  2.3e-10  0.89
# (CVXPY) Aug 16 09:00:45 AM: 43  6.2e-09  1.1e-08  4.9e-11  1.00e+00   -1.384414731e+01  -1.384414403e+01  2.3e-10  0.92
# (CVXPY) Aug 16 09:00:45 AM: 44  7.1e-09  1.0e-08  4.9e-11  1.00e+00   -1.384414733e+01  -1.384414405e+01  2.3e-10  0.95
# (CVXPY) Aug 16 09:00:45 AM: 45  7.1e-09  1.0e-08  4.9e-11  1.00e+00   -1.384414733e+01  -1.384414405e+01  2.3e-10  0.99
# (CVXPY) Aug 16 09:00:45 AM: Optimizer terminated. Time: 1.03
# (CVXPY) Aug 16 09:00:45 AM:
# (CVXPY) Aug 16 09:00:45 AM:
# (CVXPY) Aug 16 09:00:45 AM: Interior-point solution summary
# (CVXPY) Aug 16 09:00:45 AM:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Aug 16 09:00:45 AM:   Solution status : OPTIMAL
# (CVXPY) Aug 16 09:00:45 AM:   Primal.  obj: -1.3844147326e+01   nrm: 1e+00    Viol.  con: 3e-08    var: 9e-10    cones: 0e+00
# (CVXPY) Aug 16 09:00:45 AM:   Dual.    obj: -1.3844144046e+01   nrm: 5e+01    Viol.  con: 0e+00    var: 4e-08    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:45 AM: Problem status: optimal
# (CVXPY) Aug 16 09:00:45 AM: Optimal value: 9.718e-07
# (CVXPY) Aug 16 09:00:45 AM: Compilation took 1.470e+00 seconds
# (CVXPY) Aug 16 09:00:45 AM: Solver (including time spent in interface) took 1.058e+00 seconds
#
#  APRX. VALUES:
#
# 6.273914181619944 1.521893231473511
# 5.447044562977159 1.9034962227454906
# 4.650800020866037 2.166410910955764
# 3.9746156209354386 2.275041107276771
# 5.383686443378094 1.6580088148346384
# 4.64781820278145 1.9399558262873338
# 4.314418582797019 1.8593592382289768
# 4.198050042577932 1.8327145257680602
# 5.026591091267516 1.6096817359387885
# 4.6278322460759185 1.7538197520307546
# [42.05064962 30.20505643]
#
#
# {(10, True): (-1, -1, 1.030776023864746, 42.0506496152439, 30.205056426964216, -1, -1, -1, -1, -1)}
#
#
# 1. iteration:
#
#
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Aug 16 09:00:49 AM: Your problem has 697 variables, 697 constraints, and 0 parameters.
# (CVXPY) Aug 16 09:00:49 AM: It is compliant with the following grammars: DGP
# (CVXPY) Aug 16 09:00:49 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 16 09:00:49 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:49 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 16 09:00:49 AM: Reduction chain: Dgp2Dcp -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 16 09:00:49 AM: Applying reduction Dgp2Dcp
# (CVXPY) Aug 16 09:00:50 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 16 09:00:50 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 16 09:00:50 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 16 09:00:51 AM: Applying reduction MOSEK
# (CVXPY) Aug 16 09:00:51 AM: Finished problem compilation (took 1.801e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:51 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Aug 16 09:00:51 AM: Problem
# (CVXPY) Aug 16 09:00:51 AM:   Name                   :
# (CVXPY) Aug 16 09:00:51 AM:   Objective sense        : max
# (CVXPY) Aug 16 09:00:51 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 16 09:00:51 AM:   Constraints            : 4761
# (CVXPY) Aug 16 09:00:51 AM:   Cones                  : 3766
# (CVXPY) Aug 16 09:00:51 AM:   Scalar variables       : 12293
# (CVXPY) Aug 16 09:00:51 AM:   Matrix variables       : 0
# (CVXPY) Aug 16 09:00:51 AM:   Integer variables      : 0
# (CVXPY) Aug 16 09:00:51 AM:
# (CVXPY) Aug 16 09:00:51 AM: Optimizer started.
# (CVXPY) Aug 16 09:00:51 AM: Presolve started.
# (CVXPY) Aug 16 09:00:51 AM: Linear dependency checker started.
# (CVXPY) Aug 16 09:00:51 AM: Linear dependency checker terminated.
# (CVXPY) Aug 16 09:00:51 AM: Eliminator started.
# (CVXPY) Aug 16 09:00:51 AM: Freed constraints in eliminator : 37
# (CVXPY) Aug 16 09:00:51 AM: Eliminator terminated.
# (CVXPY) Aug 16 09:00:51 AM: Eliminator started.
# (CVXPY) Aug 16 09:00:51 AM: Freed constraints in eliminator : 0
# (CVXPY) Aug 16 09:00:51 AM: Eliminator terminated.
# (CVXPY) Aug 16 09:00:51 AM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Aug 16 09:00:51 AM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 16 09:00:51 AM: Lin. dep.  - number                 : 0
# (CVXPY) Aug 16 09:00:51 AM: Presolve terminated. Time: 0.01
# (CVXPY) Aug 16 09:00:51 AM: Problem
# (CVXPY) Aug 16 09:00:51 AM:   Name                   :
# (CVXPY) Aug 16 09:00:51 AM:   Objective sense        : max
# (CVXPY) Aug 16 09:00:51 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 16 09:00:51 AM:   Constraints            : 4761
# (CVXPY) Aug 16 09:00:51 AM:   Cones                  : 3766
# (CVXPY) Aug 16 09:00:51 AM:   Scalar variables       : 12293
# (CVXPY) Aug 16 09:00:51 AM:   Matrix variables       : 0
# (CVXPY) Aug 16 09:00:51 AM:   Integer variables      : 0
# (CVXPY) Aug 16 09:00:51 AM:
# (CVXPY) Aug 16 09:00:51 AM: Optimizer  - threads                : 8
# (CVXPY) Aug 16 09:00:51 AM: Optimizer  - solved problem         : the primal
# (CVXPY) Aug 16 09:00:51 AM: Optimizer  - Constraints            : 4404
# (CVXPY) Aug 16 09:00:51 AM: Optimizer  - Cones                  : 3766
# (CVXPY) Aug 16 09:00:51 AM: Optimizer  - Scalar variables       : 11936             conic                  : 11298
# (CVXPY) Aug 16 09:00:51 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY)
:   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
# (CVXPY) Aug 16 09:00:52 AM:   Solution status : OPTIMAL
# (CVXPY) Aug 16 09:00:52 AM:   Primal.  obj: -1.5162644302e+01   nrm: 1e+00    Viol.  con: 3e-08    var: 3e-10    cones: 0e+00
# (CVXPY) Aug 16 09:00:52 AM:   Dual.    obj: -1.5162642846e+01   nrm: 5e+01    Viol.  con: 0e+00    var: 2e-08    cones: 0e+00
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:52 AM: Problem status: optimal
# (CVXPY) Aug 16 09:00:52 AM: Optimal value: 2.600e-07
# (CVXPY) Aug 16 09:00:52 AM: Compilation took 1.801e+00 seconds
# (CVXPY) Aug 16 09:00:52 AM: Solver (including time spent in interface) took 1.171e+00 seconds
#
#  APRX. VALUES:
#
# 6.3294166081099705 1.56079533327279
# 5.499072651484065 1.9383032829305753
# 4.708374040657106 2.1954058073881373
# 4.036498148951108 2.2944094888614144
# 5.433635495707537 1.8145700830752405
# 4.655272971921947 2.0817491354858135
# 4.402475935783096 1.981480773367689
# 4.254256428531535 1.8163585521147523
# 5.093355517507548 1.7260594830050648
# 4.689967930881574 1.8081286364359987
# 3.9395465629216972 2.041000183117457
# [51.43342361 24.81808541]
#
#
# {(10, True): (-1, -1, 1.030776023864746, 42.0506496152439, 30.205056426964216, -1, -1, -1, -1, -1), (11, True): (-1, -1, 1.1527628898620605, 46.74203661436698, 27.511570918805546, -1, -1, -1, -1, -1)}
#
#
# 2. iteration:
#
#
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Aug 16 09:00:57 AM: Your problem has 759 variables, 759 constraints, and 0 parameters.
# (CVXPY) Aug 16 09:00:57 AM: It is compliant with the following grammars: DGP
# (CVXPY) Aug 16 09:00:57 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 16 09:00:57 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:57 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 16 09:00:57 AM: Reduction chain: Dgp2Dcp -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 16 09:00:57 AM: Applying reduction Dgp2Dcp
# (CVXPY) Aug 16 09:00:57 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 16 09:00:57 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 16 09:00:57 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 16 09:00:58 AM: Applying reduction MOSEK
# (CVXPY) Aug 16 09:00:59 AM: Finished problem compilation (took 1.999e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:00:59 AM: Invoking solver MOSEK  to obtain a solution.
#
#
# (CVXPY) Aug 16 09:00:59 AM: Problem
# (CVXPY) Aug 16 09:00:59 AM:   Name                   :
# (CVXPY) Aug 16 09:00:59 AM:   Objective sense        : max
# (CVXPY) Aug 16 09:00:59 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 16 09:00:59 AM:   Constraints            : 5191
# (CVXPY) Aug 16 09:00:59 AM:   Cones                  : 4107
# (CVXPY) Aug 16 09:00:59 AM:   Scalar variables       : 13405
# (CVXPY) Aug 16 09:00:59 AM:   Matrix variables       : 0
# (CVXPY) Aug 16 09:00:59 AM:   Integer variables      : 0
# (CVXPY) Aug 16 09:00:59 AM:
# (CVXPY) Aug 16 09:00:59 AM: Optimizer started.
# (CVXPY) Aug 16 09:00:59 AM: Presolve started.
# (CVXPY) Aug 16 09:00:59 AM: Linear dependency checker started.
# (CVXPY) Aug 16 09:00:59 AM: Linear dependency checker terminated.
# (CVXPY) Aug 16 09:00:59 AM: Eliminator started.
# (CVXPY) Aug 16 09:00:59 AM: Freed constraints in eliminator : 39
# (CVXPY) Aug 16 09:00:59 AM: Eliminator terminated.
# (CVXPY) Aug 16 09:00:59 AM: Eliminator started.
# (CVXPY) Aug 16 09:00:59 AM: Freed constraints in eliminator : 0
# (CVXPY) Aug 16 09:00:59 AM: Eliminator terminated.
# (CVXPY) Aug 16 09:00:59 AM: Eliminator - tries                  : 2                 time                   : 0.00
# (CVXPY) Aug 16 09:00:59 AM: Lin. dep.  - tries                  : 1                 time                   : 0.00
# (CVXPY) Aug 16 09:00:59 AM: Lin. dep.  - number                 : 0
# (CVXPY) Aug 16 09:00:59 AM: Presolve terminated. Time: 0.01
# (CVXPY) Aug 16 09:00:59 AM: Problem
# (CVXPY) Aug 16 09:00:59 AM:   Name                   :
# (CVXPY) Aug 16 09:00:59 AM:   Objective sense        : max
# (CVXPY) Aug 16 09:00:59 AM:   Type                   : CONIC (conic optimization problem)
# (CVXPY) Aug 16 09:00:59 AM:   Constraints            : 5191
# (CVXPY) Aug 16 09:00:59 AM:   Cones                  : 4107
# (CVXPY) Aug 16 09:00:59 AM:   Scalar variables       : 13405
# (CVXPY) Aug 16 09:00:59 AM:   Matrix variables       : 0
# (CVXPY) Aug 16 09:00:59 AM:   Integer variables      : 0
# (CVXPY) Aug 16 09:00:59 AM:
# (CVXPY) Aug 16 09:00:59 AM: Optimizer  - threads                : 8
# (CVXPY) Aug 16 09:00:59 AM: Optimizer  - solved problem         : the primal
# (CVXPY) Aug 16 09:00:59 AM: Optimizer  - Constraints            : 4803
# (CVXPY) Aug 16 09:00:59 AM: Optimizer  - Cones                  : 4107
# (CVXPY) Aug 16 09:00:59 AM: Optimizer  - Scalar variables       : 13017             conic                  : 12321
# (CVXPY) Aug 16 09:00:59 AM: Optimizer  - Semi-definite variables: 0                 scalarized             : 0
# (CVXPY) Aug 16 09:00:59 AM: Factor     - setup time             : 0.02              dense det. time        : 0.00
# (CVXPY) Aug 16 09:00:59 AM: Factor     - ML order time          : 0.01              GP order time          : 0.00
# (CVXPY) Aug 16 09:00:59 AM: Factor     - nonzeros before factor : 5.97e+04          after factor           : 1.47e+05
# (CVXPY) Aug 16 09:00:59 AM: Factor     - dense dim.             : 0                 flops                  : 6.57e+06
# (CVXPY) Aug 16 09:00:59 AM: ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# (CVXPY) Aug 16 09:00:59 AM: 0   2.3e+01  4.6e+01  4.1e+03  0.00e+00   -4.069637490e+03  0.000000000e+00   1.0e+00  0.05
# (CVXPY) Aug 16 09:00:59 AM: 1   1.6e+01  3.3e+01  3.3e+03  -8.44e-01  -3.947780652e+03  5.388575098e+00   7.3e-01  0.08
# (CVXPY) Aug 16 09:00:59 AM: 2   1.3e+01  2.7e+01  2.9e+03  -7.77e-01  -3.805233011e+03  1.845696132e+01   5.8e-01  0.10
# (CVXPY) Aug 16 09:00:59 AM: 3   8.5e+00  1.7e+01  2.1e+03  -6.85e-01  -3.403189934e+03  4.930001968e+01   3.8e-01  0.12
# (CVXPY) Aug 16 09:00:59 AM: 4   3.4e+00  7.0e+00  8.1e+02  -4.01e-01  -2.053130634e+03  1.069981973e+02   1.5e-01  0.13
# 4.257335630678121 1.8153645136157328
# 4.157257145097038 1.7994360911298752
# 5.047411561516364 1.6666922638393287
# 4.59559625247486 1.7024943228337324
# 3.820485187746391 1.9821585094793486
# 4.174026451118751 1.7494352832068965
# [47.79501693 35.25484736]
#
#
# {(10, True): (-1, -1, 1.030776023864746, 42.0506496152439, 30.205056426964216, -1, -1, -1, -1, -1), (11, True): (-1, -1, 1.1527628898620605, 46.74203661436698, 27.511570918805546, -1, -1, -1, -1, -1), (12, True): (-1, -1, 0.6275708675384521, 47.093030051581955, 30.092663066456662, -1, -1, -1, -1, -1)}
#
#
# 3. iteration:
#
#
# ===============================================================================
#                                      CVXPY
#                                      v1.2.1
# ===============================================================================
# (CVXPY) Aug 16 09:01:04 AM: Your problem has 821 variables, 821 constraints, and 0 parameters.
# (CVXPY) Aug 16 09:01:04 AM: It is compliant with the following grammars: DGP
# (CVXPY) Aug 16 09:01:04 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Aug 16 09:01:04 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Aug 16 09:01:04 AM: Compiling problem (target solver=MOSEK).
# (CVXPY) Aug 16 09:01:04 AM: Reduction chain: Dgp2Dcp -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> MOSEK
# (CVXPY) Aug 16 09:01:04 AM: Applying reduction Dgp2Dcp
# (CVXPY) Aug 16 09:01:04 AM: Applying reduction Dcp2Cone
# (CVXPY) Aug 16 09:01:05 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Aug 16 09:01:05 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Aug 16 09:01:05 AM: Applying reduction MOSEK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 testAlgorithms_CVXPY_GP()
#
# Input In [3], in testAlgorithms_CVXPY_GP()
#      30 print("\n\n" + str(iter) + ". iteration: \n\n")
#      32 numGates = numberOfGatesStart + iter * step
# ---> 33 lastGate, time = test_infiniteLadder.mainCVXPY_GP(numGates, numberOfBins, interval)
#      35 # saving values
#      36 rvs_Precise[iter, 0] = lastGate[0]
#
# File ~/Documents/GP-Optimization/src/gateSizing/test_infiniteLadder.py:314, in mainCVXPY_GP(numberOfGates, numberOfBins, interval)
#     311 objective = cp.Minimize(sum)
#     312 prob = cp.Problem(objective, constraints)
# --> 314 prob.solve(verbose=True, solver=cp.MOSEK, gp=True,
#     315            mosek_params={  'MSK_DPAR_INTPNT_CO_TOL_MU_RED': 0.1,
#     316            'MSK_DPAR_OPTIMIZER_MAX_TIME': 1200}
#     317                            # , mosek.iparam.intpnt_solve_form: mosek.solveform.dual}  # max time
#     318             )
#     320 # num_nonZeros = prob.solver_stats.extra_stats.getAttr("NumNZs")
#     321 # ObjVal = prob.solver_stats.extra_stats.getAttr("ObjVal")
#     322 # time = prob.solver_stats.extra_stats.getAttr("Runtime")
#     323 # time = prob.solver_stats.extra_stats.getAttr("dinfitem.optimizer_time")
#     324 time = prob.solver_stats.solve_time
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/problems/problem.py:481, in Problem.solve(self, *args, **kwargs)
#     479 else:
#     480     solve_func = Problem._solve
# --> 481 return solve_func(self, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/problems/problem.py:1007, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, **kwargs)
#    1004         self.unpack(chain.retrieve(soln))
#    1005         return self.value
# -> 1007 data, solving_chain, inverse_data = self.get_problem_data(
#    1008     solver, gp, enforce_dpp, ignore_dpp, verbose)
#    1010 if verbose:
#    1011     print(_NUM_SOLVER_STR)
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/problems/problem.py:655, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose)
#     652     s.LOGGER.info(
#     653              'Compiling problem (target solver=%s).', solver_name)
#     654     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 655 data, inverse_data = solving_chain.apply(self, verbose)
#     656 safe_to_cache = (
#     657     isinstance(data, dict)
#     658     and s.PARAM_PROB in data
#     659     and not any(isinstance(reduction, EvalParams)
#     660                 for reduction in solving_chain.reductions)
#     661 )
#     662 self._compilation_time = time.time() - start
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/conic_solvers/mosek_conif.py:180, in MOSEK.apply(self, problem)
#     178 def apply(self, problem):
#     179     if not problem.formatted:
# --> 180         problem = self.format_constraints(problem, self.EXP_CONE_ORDER)
#     181     if problem.x.boolean_idx or problem.x.integer_idx:  # check if either list is empty
#     182         data, inv_data = Slacks.apply(problem, [a2d.NONNEG])
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/conic_solvers/conic_solver.py:251, in ConicSolver.format_constraints(self, problem, exp_cone_order)
#     246 unspecified, remainder = divmod(problem.A.shape[0] *
#     247                                 problem.A.shape[1],
#     248                                 restruct_mat.shape[1])
#     249 reshaped_A = problem.A.reshape(restruct_mat.shape[1],
#     250                                unspecified, order='F').tocsr()
# --> 251 restructured_A = restruct_mat(reshaped_A).tocoo()
#     252 # Because of a bug in scipy versions <  1.20, `reshape`
#     253 # can overflow if indices are int32s.
#     254 restructured_A.row = restructured_A.row.astype(np.int64)
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/conic_solvers/conic_solver.py:45, in LinearOperator.__call__(self, X)
#      44 def __call__(self, X):
# ---> 45     return self._matmul(X)
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/conic_solvers/conic_solver.py:67, in as_block_diag_linear_operator.<locals>.matmul(X)
#      65 for i, op in enumerate(linear_operators):
#      66     Xi = X[col_indices[i]:col_indices[i + 1]]
# ---> 67     outputs.append(op(Xi))
#      68 return sp.vstack(outputs)
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/conic_solvers/conic_solver.py:45, in LinearOperator.__call__(self, X)
#      44 def __call__(self, X):
# ---> 45     return self._matmul(X)
#
# File ~/.local/lib/python3.10/site-packages/cvxpy/reductions/solvers/conic_solvers/conic_solver.py:39, in LinearOperator.__init__.<locals>.<lambda>(X)
#      37 def __init__(self, linear_op, shape: Tuple[int, ...]) -> None:
#      38     if sp.issparse(linear_op):
# ---> 39         self._matmul = lambda X: linear_op @ X
#      40     else:
#      41         self._matmul = linear_op
#
# File /usr/lib/python3.10/site-packages/scipy/sparse/_base.py:630, in spmatrix.__matmul__(self, other)
#     627 if isscalarlike(other):
#     628     raise ValueError("Scalar operands are not allowed, "
#     629                      "use '*' instead")
# --> 630 return self._mul_dispatch(other)
#
# File /usr/lib/python3.10/site-packages/scipy/sparse/_base.py:541, in spmatrix._mul_dispatch(self, other)
#     539     if self.shape[1] != other.shape[0]:
#     540         raise ValueError('dimension mismatch')
# --> 541     return self._mul_sparse_matrix(other)
#     543 # If it's a list or whatever, treat it like a matrix
#     544 other_a = np.asanyarray(other)
#
# File /usr/lib/python3.10/site-packages/scipy/sparse/_compressed.py:524, in _cs_matrix._mul_sparse_matrix(self, other)
#     517 fn = getattr(_sparsetools, self.format + '_matmat_maxnnz')
#     518 nnz = fn(M, N,
#     519          np.asarray(self.indptr, dtype=idx_dtype),
#     520          np.asarray(self.indices, dtype=idx_dtype),
#     521          np.asarray(other.indptr, dtype=idx_dtype),
#     522          np.asarray(other.indices, dtype=idx_dtype))
# --> 524 idx_dtype = get_index_dtype((self.indptr, self.indices,
#     525                              other.indptr, other.indices),
#     526                             maxval=nnz)
#     528 indptr = np.empty(major_axis + 1, dtype=idx_dtype)
#     529 indices = np.empty(nnz, dtype=idx_dtype)
#
# File /usr/lib/python3.10/site-packages/scipy/sparse/_sputils.py:167, in get_index_dtype(arrays, maxval, check_contents)
#     165 for arr in arrays:
#     166     arr = np.asarray(arr)
# --> 167     if not np.can_cast(arr.dtype, np.int32):
#     168         if check_contents:
#     169             if arr.size == 0:
#     170                 # a bigger type not needed
#
# File <__array_function__ internals>:180, in can_cast(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# test mean computation

def testConvolution(numberOfBins, numberOfUnaries):

    mu1 = 7
    sigma1 = 2

    mu2 = 10
    sigma2 = 1

    
    numberOfSamples = 20000000

    interval = (-5, 40)

    # DESIRED

    rv1 = np.random.normal(mu1, sigma1, numberOfSamples)
    rv2 = np.random.normal(mu2, sigma2, numberOfSamples)

    max1 = rv1 + rv2
    desired = np.array([np.mean(max1), np.std(max1)])


    # ACTUAL

    # histogram1
    h1 = histogramGenerator.get_gauss_bins_UNARY(mu1, sigma1, numberOfBins, numberOfSamples, interval, numberOfUnaries)
    h2 = histogramGenerator.get_gauss_bins_UNARY(mu2, sigma2, numberOfBins, numberOfSamples, interval, numberOfUnaries)

    
    rv1 = histogramGenerator.get_gauss_bins(mu1, sigma1, numberOfBins, numberOfSamples, interval)
    rv2 = histogramGenerator.get_gauss_bins(mu2, sigma2, numberOfBins, numberOfSamples, interval)

    
    max2 = h1.convolutionOfTwoVarsNaiveSAME_UNARY(h2)
#     max2 = rv1.convolutionOfTwoVarsShift(rv2)

    actual = np.array([max2.mean, max2.std])

    
    import matplotlib.pyplot as plt
    h1 = histogramGenerator.get_Histogram_from_UNARY(h1)
    h2 = histogramGenerator.get_Histogram_from_UNARY(h2)
    max2 = histogramGenerator.get_Histogram_from_UNARY(max2)
    
#     plt.hist(h1.edges[:-1], h1.edges, weights=h1.bins)
#     plt.hist(h2.edges[:-1], h2.edges, weights=h2.bins)
    plt.hist(max2.edges[:-1], max2.edges, weights=max2.bins)
    _ = plt.hist(max1, bins=numberOfBins, density='PDF', alpha=0.7)
    
    return (actual, desired)
    
        # TESTING

#     np.testing.assert_almost_equal(desired, actual, decimal=5)

# %%
# test convolution as wanted

numberOfBins = 50
numberOfUnaries = 50
actual, desired = testConvolution(numberOfBins, numberOfUnaries)

MAPE = 100 * np.abs((actual - desired) / desired)

print(actual, desired)
print(MAPE)
# Out:
# [17.15285714  2.11639663] [17.00003901  2.23543119]
# [0.89892812 5.32490378]

# %%
# test infinite ladder function

def LadderNumpy(numberOfBins=100, numberOfUnaries=100, number_of_nodes=1, interval=(-3, 15)):

    n_samples = 2000000
    seed = 0

    gateParams = [0.0, 1.0]

    # fix a random seed seed exists
    if seed != None:
        seed = seed
        np.random.seed(seed)

        
    ####################################
    ####### Generate Input data ########
    ####################################

    # list with inputs' mean values
    input_means = [np.random.randint(20, 70) / 10 for _ in range(number_of_nodes + 1)]
    # list with inputs' stds
    input_stds = [np.random.randint(20, 130) / 100 for _ in range(number_of_nodes + 1)]

#     input_means = [7, 10]
#     input_stds = [2, 1]
    
    # CVXPY

    constraints = []

    # generate inputs
    startingNodes = []
    for i in range(0, number_of_nodes + 1):
        g = histogramGenerator.get_gauss_bins_UNARY(input_means[i], input_stds[i], numberOfBins, n_samples,
                                                    interval, numberOfUnaries)

        node = Node(g)
        startingNodes.append(node)

        # generetate nodes
    generatedNodes = []
    for i in range(0, number_of_nodes):
        g = histogramGenerator.get_gauss_bins_UNARY(gateParams[0], gateParams[1], numberOfBins, n_samples, interval,
                                                    numberOfUnaries)

        node = Node(g)
        generatedNodes.append(node)

    # set circuit design

    # start
    startingNodes[0].setNextNodes([generatedNodes[0]])

    # upper part
    for i in range(1, number_of_nodes + 1):
        start = startingNodes[i]
        start.setNextNodes([generatedNodes[i - 1]])

        # lower part
    for i in range(0, number_of_nodes - 1):
        node = generatedNodes[i]
        node.setNextNodes([generatedNodes[i + 1]])

    delays = SSTA.calculateCircuitDelay(startingNodes, cvxpy=False, unary=True)

    delays = delays[number_of_nodes + 1:]

    rvs = []

    for gate in range(0, number_of_nodes):  # construct RVs

        finalBins = np.zeros((numberOfBins, numberOfUnaries))
        for bin in range(0, numberOfBins):
            for unary in range(0, numberOfUnaries):
                finalBins[bin, unary] = ((delays[gate].bins)[bin])[unary]

        rvs.append(RandomVariable(finalBins, generatedNodes[0].randVar.edges, unary=True))

    # simulate inputs
    nodes_simulation = [0 for _ in range(number_of_nodes)]
    inputs_simulation = MonteCarlo_inputs(input_means, input_stds, n_samples, 'Normal')

    # traverse the circuit
    nodes_simulation[0] = MonteCarlo_nodes(inputs_simulation[0], inputs_simulation[1], gateParams, n_samples)
    for i in range(1, number_of_nodes):
        nodes_simulation[i] = MonteCarlo_nodes(nodes_simulation[i - 1], inputs_simulation[i + 1], gateParams,
                                               n_samples)

    desired = get_moments_from_simulations(nodes_simulation)
    import matplotlib.pyplot as plt
    max2 = histogramGenerator.get_Histogram_from_UNARY(rvs[-1])
    
#     _ = plt.hist(nodes_simulation[0], bins=numberOfBins, density='PDF', alpha=0.7)
#     _ = plt.hist(nodes_simulation[1], bins=numberOfBins, density='PDF', alpha=0.7)
#     _ = plt.hist(nodes_simulation[2], bins=numberOfBins, density='PDF', alpha=0.7)
    plt.hist(max2.edges[:-1], max2.edges, weights=max2.bins)
    _ = plt.hist(nodes_simulation[-1], bins=numberOfBins, density='PDF', alpha=0.7)
        
    return np.array([rvs[-1].mean, rvs[-1].std]), np.array(desired[0])

# %%
numberOfNodes = 20

numberOfBins = 20
numberOfUnaries = 10

interval = (-5, 23)


actual, desired = LadderNumpy(numberOfBins, numberOfUnaries, numberOfNodes, interval=interval)

# actual = np.zeros((numberOfNodes, 2))
# desired = np.zeros((numberOfNodes, 2))

# for i in range(0, numberOfNodes):
#     actual[i, 0] = actualNonForm[i].mean
#     actual[i, 1] = actualNonForm[i].std
    
#     desired[i, 0] = desiredNonForm[i, 0]
#     desired[i, 1] = desiredNonForm[i, 1]
    


MAPE = 100 * np.abs((actual - desired) / desired)

print(actual, desired)
print(MAPE)
# Out:
# [8.3        1.14309521] [7.02773773 1.18019049]
# [18.10343985  3.14316017]

# %%
# test infinite ladder function

def LadderNumpyMaxConv(numberOfBins=100, numberOfUnaries=100, number_of_nodes=1, interval=(-3, 15)):

    n_samples = 2000000
    seed = 0

    gateParams = [0.0, 1.0]

    # fix a random seed seed exists
    if seed != None:
        seed = seed
        np.random.seed(seed)

        
    ####################################
    ####### Generate Input data ########
    ####################################

    # list with inputs' mean values
    input_means = [np.random.randint(20, 70) / 10 for _ in range(number_of_nodes + 1)]
    # list with inputs' stds
    input_stds = [np.random.randint(20, 130) / 100 for _ in range(number_of_nodes + 1)]

#     input_means = [7, 10]
#     input_stds = [2, 1]
    
    # CVXPY

    constraints = []

    # generate inputs
    startingNodes = []
    for i in range(0, number_of_nodes + 1):
        g = histogramGenerator.get_gauss_bins_UNARY(input_means[i], input_stds[i], numberOfBins, n_samples,
                                                    interval, numberOfUnaries)

        node = Node(g)
        startingNodes.append(node)

        # generetate nodes
    generatedNodes = []
    for i in range(0, number_of_nodes):
        g = histogramGenerator.get_gauss_bins_UNARY(gateParams[0], gateParams[1], numberOfBins, n_samples, interval,
                                                    numberOfUnaries)

        node = Node(g)
        generatedNodes.append(node)

    # set circuit design

    # start
    startingNodes[0].setNextNodes([generatedNodes[0]])

    # upper part
    for i in range(1, number_of_nodes + 1):
        start = startingNodes[i]
        start.setNextNodes([generatedNodes[i - 1]])

        # lower part
    for i in range(0, number_of_nodes - 1):
        node = generatedNodes[i]
        node.setNextNodes([generatedNodes[i + 1]])

    delays = SSTA.calculateCircuitDelay(startingNodes, cvxpy=False, unary=True, mosekTRI=True)

    delays = delays[number_of_nodes + 1:]

    rvs = []

    for gate in range(0, number_of_nodes):  # construct RVs

        finalBins = np.zeros((numberOfBins, numberOfUnaries))
        for bin in range(0, numberOfBins):
            for unary in range(0, numberOfUnaries):
                finalBins[bin, unary] = ((delays[gate].bins)[bin])[unary]
        
        rvs.append(RandomVariable(finalBins, generatedNodes[0].randVar.edges, unary=True))

        print(rvs[-1].mean, rvs[-1].std)
        
    # simulate inputs
    nodes_simulation = [0 for _ in range(number_of_nodes)]
    inputs_simulation = MonteCarlo_inputs(input_means, input_stds, n_samples, 'Normal')

    # traverse the circuit
    nodes_simulation[0] = MonteCarlo_nodes(inputs_simulation[0], inputs_simulation[1], gateParams, n_samples)
    for i in range(1, number_of_nodes):
        nodes_simulation[i] = MonteCarlo_nodes(nodes_simulation[i - 1], inputs_simulation[i + 1], gateParams,
                                               n_samples)

    desired = get_moments_from_simulations(nodes_simulation)
    import matplotlib.pyplot as plt
    max2 = histogramGenerator.get_Histogram_from_UNARY(rvs[-1])
    
#     _ = plt.hist(nodes_simulation[0], bins=numberOfBins, density='PDF', alpha=0.7)
#     _ = plt.hist(nodes_simulation[1], bins=numberOfBins, density='PDF', alpha=0.7)
#     _ = plt.hist(nodes_simulation[2], bins=numberOfBins, density='PDF', alpha=0.7)
    plt.hist(max2.edges[:-1], max2.edges, weights=max2.bins)
    _ = plt.hist(nodes_simulation[-1], bins=numberOfBins, density='PDF', alpha=0.7)
        
    return np.array([rvs[-1].mean, rvs[-1].std]), np.array(desired[-1])

# %%
numberOfNodes = 30

numberOfBins = 20
numberOfUnaries = 10

interval = (-4, 20)


actual, desired = LadderNumpyMaxConv(numberOfBins, numberOfUnaries, numberOfNodes, interval=interval)

# actual = np.zeros((numberOfNodes, 2))
# desired = np.zeros((numberOfNodes, 2))

# for i in range(0, numberOfNodes):
#     actual[i, 0] = actualNonForm[i].mean
#     actual[i, 1] = actualNonForm[i].std
    
#     desired[i, 0] = desiredNonForm[i, 0]
#     desired[i, 1] = desiredNonForm[i, 1]
    


MAPE = 100 * np.abs((actual - desired) / desired)

print(actual, desired)
print(MAPE)
# Out:
# 6.866666666666665 0.9977753031397177
# 6.999999999999999 1.131370849898476
# 7.279999999999999 1.3629380029920655
# 7.279999999999999 1.3629380029920655
# 7.399999999999999 1.296148139681572
# 7.399999999999999 1.296148139681572
# 7.399999999999999 1.296148139681572
# 7.399999999999999 1.296148139681572
# 7.399999999999999 1.296148139681572
# 7.399999999999999 1.296148139681572
# 7.399999999999999 1.296148139681572
# 7.3999999999999995 1.425812461886411
# 7.3999999999999995 1.7841406600200673
# 7.400000000000001 1.8516401995451028
# 7.399999999999999 1.8043425877346693
# 7.495999999999999 1.5890827542956973
# 7.485714285714285 1.5356976743287643
# 7.4 1.6970562748477138
# 7.833333333333333 1.5271614918607077
# 7.914285714285714 1.8357003890524584
# 7.959999999999998 1.903260360539251
# 8.072 1.9958997970840118
# 8.136842105263158 2.2674378135303175
# 8.145454545454545 2.5392782211285003
# 8.274285714285714 2.697972027509642
# 8.308571428571428 2.747193001548144
# 8.291891891891892 2.804280355570206
# 8.27 2.945352270951643
# 8.245454545454544 3.2166791561155783
# 8.521739130434781 3.323298063506129
# [8.52173913 3.32329806] [9.32548115 3.91398306]
# [ 8.6187727  15.09165943]

# %%
        # HEAT MAPS

# %%
# compute MAPE heatmap for Convolution - takes a long time to compute

bins = 2
unaries = 2
start = 10

meanMAPE, stdMAPE = computeMAPE(bins, unaries, start, testConvolution)
# Out:
# bins:10
# unaries: 10
# [17.5   2.25]
# [17.00041466  2.23642803]
# [2.93866564 0.60685911]
# bins:10
# unaries: 12
# [17.5   2.25]
# [16.99948492  2.23557236]
# [2.94429556 0.64536692]
# bins:12
# unaries: 10
# [15.625       3.06186218]
# [17.00011889  2.23534605]
# [ 8.08887808 36.97486234]
# bins:12
# unaries: 12
# [15.625       3.06186218]
# [16.99982416  2.23629275]
# [ 8.08728457 36.91687651]

# %%
meanMAPE = np.flip(meanMAPE, 0)
meanMAPE = np.around(meanMAPE, 2)

stdMAPE = np.around(stdMAPE, 2)
stdMAPE = np.flip(stdMAPE, 0)

# %%
# plot heatmap

import numpy as np
import matplotlib.pyplot as plt

# fig, ax = plt.subplots(figsize=(5, 5), dpi=80)

# divider = make_axes_locatable(ax)
# cax = divider.append_axes('right', size='5%', pad=0.05)

im = plt.imshow(meanMAPE)

# for i in range(0, meanMAPE.shape[0], ):
#     for j in range(meanMAPE.shape[1]):
#         text = ax.text(j, i, meanMAPE[i, j],
#                        ha="center", va="center", color="w")

locs, labels = plt.xticks()  # Get the current locations and labels.
plt.xticks(np.arange(0, unaries), np.arange(start, start+unaries*2, step=2))
plt.yticks(np.arange(0, bins), np.flip(np.arange(start, start+bins*2, step=2)))

plt.xlabel('Number of unary variables')
plt.ylabel('Number of bins')
plt.title('Convolution, MAPE of mean')

# fig.tight_layout()

plt.colorbar()

# plt.savefig("Inputs/testConvolution/meanHeatMap.jpeg", dpi=300)
plt.show()


# fig, ax = plt.subplots(figsize=(5, 5), dpi=80)
im = plt.imshow(stdMAPE)
plt.colorbar()

# for i in range(0, stdMAPE.shape[0], ):
#     for j in range(stdMAPE.shape[1]):
#         text = ax.text(j, i, stdMAPE[i, j],
#                        ha="center", va="center", color="w")

locs, labels = plt.xticks()  # Get the current locations and labels.
plt.xticks(np.arange(0, unaries), np.arange(start, start+unaries*2, step=2))
plt.yticks(np.arange(0, bins), np.flip(np.arange(start, start+bins*2, step=2)))



plt.xlabel('Number of unary variables')
plt.ylabel('Number of bins')
plt.title('Convolution, MAPE of std')


# fig.tight_layout()

# plt.savefig("Inputs/testConvolution/stdHeatMap.jpeg", dpi=300)
plt.show()

# %%
# compute MAPE heatmap for MAXIMUM - takes a long time to compute


bins = 2
unaries = 2
start = 10

meanMAPE, stdMAPE = computeMAPE(bins, unaries, start, testMax)
# Out:
# bins:10
# unaries: 10
# [11.25        2.04124145]
# [12.07199516  1.95055366]
# [6.80910774 4.64933578]
# bins:10
# unaries: 12
# [11.25        2.04124145]
# [12.0716215   1.95046253]
# [6.8062232  4.65422544]
# bins:12
# unaries: 10
# [12.70833333  1.70103454]
# [12.07170314  1.95066595]
# [ 5.27373962 12.79724028]
# bins:12
# unaries: 12
# [11.66666667  2.32923748]
# [12.07272689  1.95050342]
# [ 3.36345074 19.41724669]

# %%
meanMAPE = np.around(meanMAPE, 2)
meanMAPE = np.flip(meanMAPE, 0)

stdMAPE = np.around(stdMAPE, 2)
stdMAPE = np.flip(stdMAPE, 0)

# %%
# plot heatmap

fig, ax = plt.subplots(figsize=(13, 13), dpi=80)

im = ax.imshow(meanMAPE)

for i in range(0, meanMAPE.shape[0], ):
    for j in range(meanMAPE.shape[1]):
        text = ax.text(j, i, meanMAPE[i, j],
                       ha="center", va="center", color="w")

locs, labels = plt.xticks()  # Get the current locations and labels.
plt.xticks(np.arange(0, unaries), np.arange(start, start+unaries*2, step=2))
plt.yticks(np.arange(0, bins), np.flip(np.arange(start, start+bins*2, step=2)))


fig.tight_layout()

plt.savefig("Inputs/testMAX/meanHeatMap.jpeg", dpi=100)
plt.show()



fig, ax = plt.subplots(figsize=(13, 13), dpi=80)
im = ax.imshow(stdMAPE)

for i in range(0, stdMAPE.shape[0], ):
    for j in range(stdMAPE.shape[1]):
        text = ax.text(j, i, stdMAPE[i, j],
                       ha="center", va="center", color="w")

locs, labels = plt.xticks()  # Get the current locations and labels.
plt.xticks(np.arange(0, unaries), np.arange(start, start+unaries*2, step=2))
plt.yticks(np.arange(0, bins), np.flip(np.arange(start, start+bins*2, step=2)))


fig.tight_layout()

plt.savefig("Inputs/testMAX/stdHeatMap.jpeg", dpi=100)
plt.show()

# %%
# compute MAPE heatmap for infinite ladder - takes a long time to compute

bins = 2
unaries = 2
start = 10

meanMAPE, stdMAPE = computeMAPE(bins, unaries, start, LadderNumpy)
# Out:
# bins:10
# unaries: 10
# [6.5 0. ]
# [7.04774699 1.23018441]
# [  7.77194452 100.        ]
# bins:10
# unaries: 12
# [6.5 0. ]
# [7.04774699 1.23018441]
# [  7.77194452 100.        ]
# bins:12
# unaries: 10
# [6.5        2.41666667]
# [7.04774699 1.23018441]
# [ 7.77194452 96.447512  ]
# bins:12
# unaries: 12
# [6.5        2.41666667]
# [7.04774699 1.23018441]
# [ 7.77194452 96.447512  ]

# %%
meanMAPE = np.around(meanMAPE, 2)
meanMAPE = np.flip(meanMAPE, 0)

stdMAPE = np.around(stdMAPE, 2)
stdMAPE = np.flip(stdMAPE, 0)

# %%
# plot heatmap

fig, ax = plt.subplots(figsize=(13, 13), dpi=80)

im = ax.imshow(meanMAPE)

for i in range(0, meanMAPE.shape[0], ):
    for j in range(meanMAPE.shape[1]):
        text = ax.text(j, i, meanMAPE[i, j],
                       ha="center", va="center", color="w")

locs, labels = plt.xticks()  # Get the current locations and labels.
plt.xticks(np.arange(0, unaries), np.arange(start, start+unaries*2, step=2))
plt.yticks(np.arange(0, bins), np.flip(np.arange(start, start+bins*2, step=2)))


fig.tight_layout()

plt.savefig("Inputs/testInfiniteLadder/meanHeatMap.jpeg", dpi=100)
plt.show()



fig, ax = plt.subplots(figsize=(13, 13), dpi=80)
im = ax.imshow(stdMAPE)

for i in range(0, stdMAPE.shape[0], ):
    for j in range(stdMAPE.shape[1]):
        text = ax.text(j, i, stdMAPE[i, j],
                       ha="center", va="center", color="w")

locs, labels = plt.xticks()  # Get the current locations and labels.
plt.xticks(np.arange(0, unaries), np.arange(start, start+unaries*2, step=2))
plt.yticks(np.arange(0, bins), np.flip(np.arange(start, start+bins*2, step=2)))


fig.tight_layout()

plt.savefig("Inputs/testInfiniteLadder/stdHeatMap.jpeg", dpi=100)
plt.show()
